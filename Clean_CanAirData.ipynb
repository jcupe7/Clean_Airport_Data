# %% [markdown]
# The main goal of this notebook is to clean data from a dataset and present relevant metrics

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
air_df = pd.read_csv('23100006.csv')
air_df.head()
# Out:
#   REF_DATE     GEO           DGUID             Airports Type of power plant  \
# 0  1997-01  Canada  2016A000011124  Total, all airports         Jet engines
# 1  1997-01  Canada  2016A000011124  Total, all airports    Turbo-propellers
# 2  1997-01  Canada  2016A000011124  Total, all airports      Piston engines
# 3  1997-01  Canada  2016A000011124  Total, all airports         Helicopters
# 4  1997-01  Canada  2016A000011124  Total, all airports             Gliders
#
#       UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  VALUE  \
# 0  Number     223         units          0  v32210997      1.1.1  85975
# 1  Number     223         units          0  v32210998      1.1.2  62132
# 2  Number     223         units          0  v32210999      1.1.3  53244
# 3  Number     223         units          0  v32211000      1.1.4  10480
# 4  Number     223         units          0  v32211001      1.1.5     33
#
#    STATUS  SYMBOL TERMINATED  DECIMALS
# 0     NaN     NaN        NaN         0
# 1     NaN     NaN        NaN         0
# 2     NaN     NaN        NaN         0
# 3     NaN     NaN        NaN         0
# 4     NaN     NaN        NaN         0
